# %%
import pandas as pd
import gspread
from oauth2client.service_account import ServiceAccountCredentials

# %%
df_Kak_Baseline_Test_revised = pd.read_excel("Kak_Baseline_Test_revised.xlsx")

# %%
df_Kak_Baseline_Test_revised
# Out:
#                     uid bd_earner_only  bd_members_respfor  \
# 0    part/KE16012104001            Yes                  12
# 1    part/KE16012104002            Yes                   1
# 2    part/KE16012104003            Yes                  11
# 3    part/KE16012104004            Yes                   8
# 4    part/KE16012104005            Yes                  10
# ..                  ...            ...                 ...
# 897  part/KE16012104898            Yes                   8
# 898  part/KE16012104899            Yes                  11
# 899  part/KE16012104900            Yes                   4
# 900  part/KE16012104901             No                   7
# 901  part/KE16012104902            Yes                   4
#
#                                bd_bizsector  e_total_employees  \
# 0                                   Fashion                  3
# 1                           Shop â€“ Retail                  1
# 2                       Clothes And Textile                  1
# ...

# %%
df_Kak_Baseline_Test_revised = df_Kak_Baseline_Test_revised.dropna(axis='index',how='any',subset=['CB'])

df_Kak_Baseline_Test_revised = df_Kak_Baseline_Test_revised.drop('CC',axis=1)

# %%
df_Kak_Baseline_Test_revised = df_Kak_Baseline_Test_revised.set_index('uid')

# %%
df_Kak_Baseline_Test_revised = df_Kak_Baseline_Test_revised.reset_index()

# %%
df_Kak_Baseline_Test_revised
# Out:
#                     uid bd_earner_only  bd_members_respfor  \
# 0    part/KE16012104003            Yes                  11
# 1    part/KE16012104004            Yes                   8
# 2    part/KE16012104006            Yes                  13
# 3    part/KE16012104010            Yes                   7
# 4    part/KE16012104012            Yes                  11
# ..                  ...            ...                 ...
# 296  part/KE16012104890            Yes                   4
# 297  part/KE16012104895            Yes                   5
# 298  part/KE16012104898            Yes                   8
# 299  part/KE16012104900            Yes                   4
# 300  part/KE16012104901             No                   7
#
#                        bd_bizsector  e_total_employees  e_fulltime_employees  \
# 0               Clothes And Textile                  1                     1
# 1                   Shop â€“ Retail                  3                     1
# ...

# %%
df_Kak_endline_Test_revised = pd.read_excel("Kak_endline_Test_revised.xlsx")

# %%
df_Kak_endline_Test_revised
# Out:
#               unique_id cd_gender cd_nationality                    cd_strata  \
# 0                     7      Male         Kenyan  Host community entrepreneur
# 1                     8    Female         Kenyan  Host community entrepreneur
# 2    PART/KE16012104001      Male      Congolese                      Refugee
# 3    PART/KE16012104002      Male       Sudanese                      Refugee
# 4    PART/KE16012104003    Female         Somali                      Refugee
# ..                  ...       ...            ...                          ...
# 532  PART/KE16012104896    Female         Somali                      Refugee
# 533  PART/KE16012104897    Female         Kenyan                         Host
# 534  PART/KE16012104898      Male         Somali                      Refugee
# 535  PART/KE16012104899    Female         Somali                      Refugee
# 536  PART/KE16012104900    Female         Somali                      Refugee
#
# ...

# %%
df_Kak_endline_Test_revised = df_Kak_endline_Test_revised.drop('bd_biz_failure_reasn_5',axis=1)

# %%
df_Kak_endline_Test_revised
# Out:
#               unique_id cd_gender cd_nationality                    cd_strata  \
# 0                     7      Male         Kenyan  Host community entrepreneur
# 1                     8    Female         Kenyan  Host community entrepreneur
# 2    PART/KE16012104001      Male      Congolese                      Refugee
# 3    PART/KE16012104002      Male       Sudanese                      Refugee
# 4    PART/KE16012104003    Female         Somali                      Refugee
# ..                  ...       ...            ...                          ...
# 532  PART/KE16012104896    Female         Somali                      Refugee
# 533  PART/KE16012104897    Female         Kenyan                         Host
# 534  PART/KE16012104898      Male         Somali                      Refugee
# 535  PART/KE16012104899    Female         Somali                      Refugee
# 536  PART/KE16012104900    Female         Somali                      Refugee
#
# ...

# %%
df_Kak_endline_Test_revised = df_Kak_endline_Test_revised.drop('bd_biz_failure_reasn_4',axis=1)

# %%
df_Kak_endline_Test_revised
# Out:
#               unique_id cd_gender cd_nationality                    cd_strata  \
# 0                     7      Male         Kenyan  Host community entrepreneur
# 1                     8    Female         Kenyan  Host community entrepreneur
# 2    PART/KE16012104001      Male      Congolese                      Refugee
# 3    PART/KE16012104002      Male       Sudanese                      Refugee
# 4    PART/KE16012104003    Female         Somali                      Refugee
# ..                  ...       ...            ...                          ...
# 532  PART/KE16012104896    Female         Somali                      Refugee
# 533  PART/KE16012104897    Female         Kenyan                         Host
# 534  PART/KE16012104898      Male         Somali                      Refugee
# 535  PART/KE16012104899    Female         Somali                      Refugee
# 536  PART/KE16012104900    Female         Somali                      Refugee
#
# ...

# %%
df_Kak_endline_Test_revised = df_Kak_endline_Test_revised.drop('bd_biz_failure_reasn_3',axis=1)

# %%
df_Kak_endline_Test_revised = df_Kak_endline_Test_revised.drop(['bd_biz_failure_reasn_2','bd_biz_failure_reasn_6'], axis=1)

# %%
df_Kak_endline_Test_revised = df_Kak_endline_Test_revised.drop(['bd_biz_failure_reasn_1','bd_biz_failure_reasn_7','bd_biz_failure_reasn_8'], axis=1)

# %%
df_Kak_endline_Test_revised = df_Kak_endline_Test_revised.drop(['bd_biz_failure_reasn','consent','bd_biz_failure_reasn_otr','refusal','otherpecify','thanks'],axis=1)

# %%
df_Kak_endline_Test_revised = df_Kak_endline_Test_revised.drop(['liv_cookingfuel_otr','Section_G_Section_G_proved_in_th'],axis=1)

# %%
df_Kak_endline_Test_revised
# Out:
#               unique_id cd_gender cd_nationality                    cd_strata  \
# 0                     7      Male         Kenyan  Host community entrepreneur
# 1                     8    Female         Kenyan  Host community entrepreneur
# 2    PART/KE16012104001      Male      Congolese                      Refugee
# 3    PART/KE16012104002      Male       Sudanese                      Refugee
# 4    PART/KE16012104003    Female         Somali                      Refugee
# ..                  ...       ...            ...                          ...
# 532  PART/KE16012104896    Female         Somali                      Refugee
# 533  PART/KE16012104897    Female         Kenyan                         Host
# 534  PART/KE16012104898      Male         Somali                      Refugee
# 535  PART/KE16012104899    Female         Somali                      Refugee
# 536  PART/KE16012104900    Female         Somali                      Refugee
#
# ...

# %%
df_Kak_endline_Test_revised = df_Kak_endline_Test_revised.dropna(axis= 'index', how='any',subset=['ss_aecscrvcs_recommend_reasn'])

# %%
df_Kak_endline_Test_revised = df_Kak_endline_Test_revised.dropna(axis= 'index', how='any',subset=['end_commentyes'])

# %%
df_Kak_endline_Test_revised = df_Kak_endline_Test_revised.reset_index()

# %%
df_Kak_endline_Test_revised
# Out:
#     index           unique_id cd_gender cd_nationality  \
# 0       1                   8    Female         Kenyan
# 1       5  PART/KE16012104004      Male       Sudanese
# 2      13  PART/KE16012104014      Male       Sudanese
# 3      24  PART/KE16012104031      Male         Somali
# 4      30  PART/KE16012104041    Female      Ethiopian
# ..    ...                 ...       ...            ...
# 80    511  PART/KE16012104850    Female         Kenyan
# 81    512  PART/KE16012104854      Male         Kenyan
# 82    521  PART/KE16012104874    Female         Kenyan
# 83    528  PART/KE16012104886      Male         Kenyan
# 84    530  PART/KE16012104892      Male         Kenyan
#
#                       cd_strata  cd_age client_location  bd_location  \
# 0   Host community entrepreneur      32     Kakuma town  Kakuma town
# 1                       Refugee      48        Kakuma 3     Kakuma 3
# 2                       Refugee      31        Kakuma 4     Kakuma 4
# ...

# %%
df_Kak_endline_Test_revised = df_Kak_endline_Test_revised.set_index('unique_id')

# %%
df_Kak_endline_Test_revised = df_Kak_endline_Test_revised.reset_index()

# %%
df_Kak_endline_Test_revised = df_Kak_endline_Test_revised.drop('index',axis=1)

# %%
df_Kak_endline_Test_revised
# Out:
#              unique_id cd_gender cd_nationality                    cd_strata  \
# 0                    8    Female         Kenyan  Host community entrepreneur
# 1   PART/KE16012104004      Male       Sudanese                      Refugee
# 2   PART/KE16012104014      Male       Sudanese                      Refugee
# 3   PART/KE16012104031      Male         Somali                      Refugee
# 4   PART/KE16012104041    Female      Ethiopian                      Refugee
# ..                 ...       ...            ...                          ...
# 80  PART/KE16012104850    Female         Kenyan                         Host
# 81  PART/KE16012104854      Male         Kenyan                         Host
# 82  PART/KE16012104874    Female         Kenyan                         Host
# 83  PART/KE16012104886      Male         Kenyan                         Host
# 84  PART/KE16012104892      Male         Kenyan                         Host
#
# ...

# %%
df_Survey_Codebook_revised = pd.read_excel("Survey Codebook_revised.xlsx")

# %%
df_Survey_Codebook_revised
# Out:
#                    Section                            Survey Question (Label)  \
# 0                      NaN                                                NaN
# 1   A. Client Demographics                                                NaN
# 2                      NaN                           Surveyor/Enumerator name
# 3                      NaN                                             Gender
# 4                      NaN                                  Name/Clients name
# ..                     ...                                                ...
# 94                     NaN  if you are not in a saving group and you are s...
# 95                     NaN                       if other saving mode specify
# 96                     NaN               What is your second income resource?
# 97                     NaN     How much money yourself do you save per month?
# 98                     NaN  Do you feel that there is a change in househol...
#
#              variable name
# ...

# %%
df_Survey_Codebook_revised = df_Survey_Codebook_revised.dropna(axis= 'index',how='any',subset=['Survey Question (Label)'])

# %%
df_Survey_Codebook_revised
# Out:
#    Section                            Survey Question (Label)  \
# 2      NaN                           Surveyor/Enumerator name
# 3      NaN                                             Gender
# 4      NaN                                  Name/Clients name
# 5      NaN                                  Age of respondent
# 6      NaN                                    Age group/range
# ..     ...                                                ...
# 94     NaN  if you are not in a saving group and you are s...
# 95     NaN                       if other saving mode specify
# 96     NaN               What is your second income resource?
# 97     NaN     How much money yourself do you save per month?
# 98     NaN  Do you feel that there is a change in househol...
#
#              variable name
# 2              cd_enum_name
# 3                 cd_gender
# 4                   cd_name
# 5                    cd_age
# 6               cd_agegroup
# ..                      ...
# ...

# %%
 df_Survey_Codebook_revised = df_Survey_Codebook_revised.drop('Section',axis=1)

# %%
df_Survey_Codebook_revised
# Out:
#                               Survey Question (Label)           variable name
# 2                            Surveyor/Enumerator name             cd_enum_name
# 3                                              Gender                cd_gender
# 4                                   Name/Clients name                  cd_name
# 5                                   Age of respondent                   cd_age
# 6                                     Age group/range              cd_agegroup
# ..                                                ...                      ...
# 94  if you are not in a saving group and you are s...      liv_sgno_saveany_hw
# 95                       if other saving mode specify  liv_sgno_saveany_hw_otr
# 96               What is your second income resource?     liv_second_incsource
# 97     How much money yourself do you save per month?  liv_sgno_saveany_hwmuch
# 98  Do you feel that there is a change in househol...    liv_livingcond_change
#
# [88 rows x 2 columns]

# %%
df_Survey_Codebook_revised = df_Survey_Codebook_revised.set_index('Survey Question (Label)')

# %%
df_Survey_Codebook_revised = df_Survey_Codebook_revised.reset_index()

# %%
df_Survey_Codebook_revised
# Out:
#                               Survey Question (Label)           variable name
# 0                            Surveyor/Enumerator name             cd_enum_name
# 1                                              Gender                cd_gender
# 2                                   Name/Clients name                  cd_name
# 3                                   Age of respondent                   cd_age
# 4                                     Age group/range              cd_agegroup
# ..                                                ...                      ...
# 83  if you are not in a saving group and you are s...      liv_sgno_saveany_hw
# 84                       if other saving mode specify  liv_sgno_saveany_hw_otr
# 85               What is your second income resource?     liv_second_incsource
# 86     How much money yourself do you save per month?  liv_sgno_saveany_hwmuch
# 87  Do you feel that there is a change in househol...    liv_livingcond_change
#
# [88 rows x 2 columns]

# %%
import mysql.connector

mydb = mysql.connector.connect(
  host="localhost",
  user="root",
  password="arsa"
)

mycursor = mydb.cursor()

mycursor.execute("CREATE DATABASE INKOMOKO_DB")

# %%
mydb = mysql.connector.connect(
  host="localhost",
  user="root",
  password="arsa",
  database="INKOMOKO_DB"
)

mycursor = mydb.cursor()

mycursor.execute("CREATE TABLE Survey_Codebook_revised (SurveyQuestion VARCHAR(255), variableName VARCHAR(255))")

# %%
mydb = mysql.connector.connect(
  host="localhost",
  user="root",
  password="arsa",
  database="INKOMOKO_DB"
)

mycursor = mydb.cursor()

mycursor.execute("CREATE TABLE Kak_endline_Test_revised (unique_id VARCHAR(255), cd_gender VARCHAR(255),cd_nationality VARCHAR(255) ,cd_strata VARCHAR(255),cd_age NVARCHAR(255),client_location VARCHAR(255),bd_location VARCHAR(255),cd_enum_name VARCHAR(255),consent_yesno INT,surv_date DATE)")

# %%
mydb = mysql.connector.connect(
  host="localhost",
  user="root",
  password="arsa",
  database="INKOMOKO_DB"
)

mycursor = mydb.cursor()

mycursor.execute("CREATE TABLE Kak_Baseline_Test_revised (uid VARCHAR(255), bd_earner_only VARCHAR(255),bd_members_respfor INT ,bd_bizsector VARCHAR(255),e_total_employees INT,e_fulltime_employees INT,e_parttime_employees INT,e_casual_employees INT,e_male_employees INT,e_female_employees INT)")

# %%
from pandas.io import sql
import MySQLdb
import sqlalchemy
import pymysql
import pandas as pd

conni=pymysql.connect(host='localhost',port=int(3306),user='root',passwd='arsa',db='INKOMOKO_DB')

df_Survey_Codebook_revised.to_sql(con=conni,name='Survey_Codebook_revised')


df_Kak_Baseline_Test_revised.to_sql(con=conni,name='Kak_Baseline_Test_revised')

df_Kak_endline_Test_revised.to_sql(con=conni,name='Kak_endline_Test_revised')
